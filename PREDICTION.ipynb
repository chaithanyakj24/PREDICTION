# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("new.csv")
data
# Out:
#      S.NO  GENDER  REGION  SSLC_MARKS    SSLC_BOARD  PUC_MARKS     PUC_BOARD  \
# 0       1    Male   Urban        87.6          CBSE       95.0          CBSE
# 1       2    Male   Rural        78.4   State Board       85.0   State Board
# 2       3  Female   Urban        92.5          ICSE       90.2   State Board
# 3       4  Female   Rural        83.9   State Board       81.6   State Board
# 4       5  Female   Rural        79.3   State Board       82.0   State Board
# ..    ...     ...     ...         ...           ...        ...           ...
# 695   696  Female   Rural        67.4   State Board       70.2   State Board
# 696   697    Male   Urban        86.7          ICSE       83.5   State Board
# 697   698  Female   Rural        71.9   State Board       84.7   State Board
# 698   699    Male   Urban        78.5   State Board       85.5   State Board
# 699   700  Female   Rural        69.2          ICSE       66.7   State Board
#
# ...

# %%
data.shape
# Out:
# (700, 12)

# %%
print("Number of Rows",data.shape[0])
print("Number of columns",data.shape[1])
# Out:
# Number of Rows 700
# Number of columns 12

# %% [raw]
# DATA PREPROCESSING

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   S.NO             700 non-null    int64
#  1   GENDER           700 non-null    object
#  2   REGION           700 non-null    object
#  3   SSLC_MARKS       700 non-null    float64
#  4   SSLC_BOARD       700 non-null    object
#  5   PUC_MARKS        700 non-null    float64
#  6   PUC_BOARD        700 non-null    object
#  7   CGPA             700 non-null    float64
#  8   INTERNSHIP       700 non-null    object
#  9   WORK EXPERIENCE  700 non-null    object
#  10  BRANCH           700 non-null    object
#  11  STATUS           700 non-null    object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 65.8+ KB

# %%
data.isnull()
# Out:
#       S.NO  GENDER  REGION  SSLC_MARKS  SSLC_BOARD  PUC_MARKS  PUC_BOARD  \
# 0    False   False   False       False       False      False      False
# 1    False   False   False       False       False      False      False
# 2    False   False   False       False       False      False      False
# 3    False   False   False       False       False      False      False
# 4    False   False   False       False       False      False      False
# ..     ...     ...     ...         ...         ...        ...        ...
# 695  False   False   False       False       False      False      False
# 696  False   False   False       False       False      False      False
# 697  False   False   False       False       False      False      False
# 698  False   False   False       False       False      False      False
# 699  False   False   False       False       False      False      False
#
#       CGPA  INTERNSHIP  WORK EXPERIENCE  BRANCH  STATUS
# ...

# %%
data.isnull().sum()
# Out:
# S.NO               0
# GENDER             0
# REGION             0
# SSLC_MARKS         0
# SSLC_BOARD         0
# PUC_MARKS          0
# PUC_BOARD          0
# CGPA               0
# INTERNSHIP         0
# WORK EXPERIENCE    0
# BRANCH             0
# STATUS             0
# dtype: int64

# %% [raw]
# EXPLORATORY DATA ANALYSIS

# %%
data.columns
# Out:
# Index(['S.NO', 'GENDER', 'REGION', 'SSLC_MARKS', 'SSLC_BOARD', 'PUC_MARKS',
#        'PUC_BOARD', 'CGPA', 'INTERNSHIP', 'WORK EXPERIENCE', 'BRANCH',
#        'STATUS'],
#       dtype='object')

# %%
data['STATUS'].unique()
# Out:
# array(['Placed', 'NotPlaced'], dtype=object)

# %%
data['STATUS'].value_counts()
# Out:
# STATUS
# Placed       373
# NotPlaced    327
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['S.NO', 'GENDER', 'REGION', 'SSLC_MARKS', 'SSLC_BOARD', 'PUC_MARKS',
#        'PUC_BOARD', 'CGPA', 'INTERNSHIP', 'WORK EXPERIENCE', 'BRANCH',
#        'STATUS'],
#       dtype='object')

# %%
data=data.drop(['S.NO'],axis=1)

# %%
data.head(1)
# Out:
#   GENDER  REGION  SSLC_MARKS SSLC_BOARD  PUC_MARKS PUC_BOARD  CGPA INTERNSHIP  \
# 0   Male   Urban        87.6       CBSE       95.0      CBSE   8.7        Yes
#
#   WORK EXPERIENCE BRANCH  STATUS
# 0              No     CS  Placed

# %%
data['STATUS'].value_counts()
# Out:
# STATUS
# Placed       373
# NotPlaced    327
# Name: count, dtype: int64

# %%
data['GENDER'].value_counts()
# Out:
# GENDER
# Male      388
# Female    312
# Name: count, dtype: int64

# %%
data['REGION'].value_counts()
# Out:
# REGION
# Rural    352
# Urban    348
# Name: count, dtype: int64

# %%
data['SSLC_BOARD'].value_counts()
# Out:
# SSLC_BOARD
# State Board    326
# CBSE           195
# ICSE           179
# Name: count, dtype: int64

# %%
data['PUC_BOARD'].value_counts()
# Out:
# PUC_BOARD
# State Board    508
# CBSE           192
# Name: count, dtype: int64

# %%
data['INTERNSHIP'].value_counts()
# Out:
# INTERNSHIP
# Yes    354
# No     346
# Name: count, dtype: int64

# %%
data['WORK EXPERIENCE'].value_counts()
# Out:
# WORK EXPERIENCE
# No     415
# Yes    285
# Name: count, dtype: int64

# %%
data['BRANCH'].value_counts()
# Out:
# BRANCH
# CS    175
# ME    124
# EE    120
# IS    112
# EC    100
# CV     69
# Name: count, dtype: int64

# %%
data["GENDER"]=data["GENDER"].map({'Male':0,'Female':1})
data["REGION"]=data["REGION"].map({' Rural':0,' Urban':1})
data["SSLC_BOARD"]=data["SSLC_BOARD"].map({' State Board':0,' CBSE':1,' ICSE':2})
data["PUC_BOARD"]=data["PUC_BOARD"].map({" State Board":0," CBSE":1})
data["INTERNSHIP"]=data["INTERNSHIP"].map({" Yes":0," No":1})
data["WORK EXPERIENCE"]=data["WORK EXPERIENCE"].map({" Yes":0," No":1})
data["BRANCH"]=data["BRANCH"].map({" CS":0," ME":1," EE":2," IS":3," EC":4," CV":5})
data["STATUS"]=data["STATUS"].map({"Placed":0,"NotPlaced":1})

# %%
data.head()
# Out:
#    GENDER  REGION  SSLC_MARKS  SSLC_BOARD  PUC_MARKS  PUC_BOARD  CGPA  \
# 0       0       1        87.6           1       95.0          1   8.7
# 1       0       0        78.4           0       85.0          0   7.8
# 2       1       1        92.5           2       90.2          0   9.1
# 3       1       0        83.9           0       81.6          0   7.5
# 4       1       0        79.3           0       82.0          0   8.3
#
#    INTERNSHIP  WORK EXPERIENCE  BRANCH  STATUS
# 0           0                1       0       0
# 1           1                1       4       0
# 2           0                1       3       0
# 3           1                1       1       1
# 4           0                1       0       0

# %%
import seaborn as sns
sns.distplot(data['GENDER']);

# %%
data.head()
# Out:
#    GENDER  REGION  SSLC_MARKS  SSLC_BOARD  PUC_MARKS  PUC_BOARD  CGPA  \
# 0       0       1        87.6           1       95.0          1   8.7
# 1       0       0        78.4           0       85.0          0   7.8
# 2       1       1        92.5           2       90.2          0   9.1
# 3       1       0        83.9           0       81.6          0   7.5
# 4       1       0        79.3           0       82.0          0   8.3
#
#    INTERNSHIP  WORK EXPERIENCE  BRANCH  STATUS
# 0           0                1       0       0
# 1           1                1       4       0
# 2           0                1       3       0
# 3           1                1       1       1
# 4           0                1       0       0

# %%
data.columns
# Out:
# Index(['GENDER', 'REGION', 'SSLC_MARKS', 'SSLC_BOARD', 'PUC_MARKS',
#        'PUC_BOARD', 'CGPA', 'INTERNSHIP', 'WORK EXPERIENCE', 'BRANCH',
#        'STATUS'],
#       dtype='object')

# %%
x=data.drop('STATUS',axis=1)
y=data['STATUS']
y
x
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.20,random_state=42)
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
y_pred
from sklearn.metrics import accuracy_score
score1=accuracy_score(y_test,y_pred)
print(score1)
# Out:
# 0.9214285714285714

# %%
data.head()
# Out:
#    GENDER  REGION  SSLC_MARKS  SSLC_BOARD  PUC_MARKS  PUC_BOARD  CGPA  \
# 0       0       1        87.6           1       95.0          1   8.7
# 1       0       0        78.4           0       85.0          0   7.8
# 2       1       1        92.5           2       90.2          0   9.1
# 3       1       0        83.9           0       81.6          0   7.5
# 4       1       0        79.3           0       82.0          0   8.3
#
#    INTERNSHIP  WORK EXPERIENCE  BRANCH  STATUS
# 0           0                1       0       0
# 1           1                1       4       0
# 2           0                1       3       0
# 3           1                1       1       1
# 4           0                1       0       0

# %%
test=pd.DataFrame({
    'GENDER':0,
    'REGION':0,
    'SSLC_MARKS':90.6,
    'SSLC_BOARD':2,
    'PUC_MARKS':50,
    'PUC_BOARD':1,
    'CGPA':9.0,
    'INTERNSHIP':1,
    'WORK EXPERIENCE':0,
    'BRANCH':5,
    },index=[0])
lr=LogisticRegression()
lr.fit(x,y)
# Out:
# LogisticRegression()

# %%
p=lr.predict(test)
prob=lr.predict_proba(test)
if p==1:
    print("Congratulations you have the chances of getting placed")
else:
    print("Sorry for this time! Work more harder and visit again")
# Out:
# Sorry for this time! Work more harder and visit again

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the dataset
data = pd.read_csv("new.csv")

# Categorize SSLC marks, PUC marks, and CGPA into bins
data['SSLC_MARKS'] = pd.cut(data['SSLC_MARKS'], bins=[0, 60, 70, 80, 90, 100], labels=['Below 60', '60-70', '70-80', '80-90', '90-100'])
data['PUC_MARKS'] = pd.cut(data['PUC_MARKS'], bins=[0, 60, 70, 80, 90, 100], labels=['Below 60', '60-70', '70-80', '80-90', '90-100'])
data['CGPA'] = pd.cut(data['CGPA'], bins=[0, 6, 7, 8, 9, 10], labels=['Below 6', '6-7', '7-8', '8-9', '9-10'])

# Group by each categorical variable and calculate counts of individuals
categorical_variables = ['REGION', 'INTERNSHIP', 'BRANCH', 'SSLC_MARKS', 'PUC_MARKS', 'CGPA']

plt.figure(figsize=(18, 12))

for i, category in enumerate(categorical_variables):
    placed_counts = data[data['STATUS'] == 'Placed'].groupby(category).size()
    total_counts = data.groupby(category).size()
    percentages = (placed_counts / total_counts) * 100
    categories = placed_counts.index

    # Plotting bar chart
    plt.subplot(2, 3, i+1)
    plt.bar(categories, percentages, color='skyblue')
    plt.ylabel('Percentage (%)')
    plt.xticks(rotation=45, ha='right')

    # Adding percentage labels above each bar
    for j, percentage in enumerate(percentages):
        plt.text(j, percentage + 1, f"{percentage:.1f}%", ha='center')

    # Adding figure tag below each subplot
    plt.text(0.5, -0.2, f"Figure 6.2.{i+1}: Placed Candidates by {category}", transform=plt.gca().transAxes, ha='center', fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the dataset
data = pd.read_csv("new.csv")

# Categorize SSLC marks, PUC marks, and CGPA into bins
data['SSLC_MARKS'] = pd.cut(data['SSLC_MARKS'], bins=[0, 60, 70, 80, 90, 100], labels=['Below 60', '60-70', '70-80', '80-90', '90-100'])
data['PUC_MARKS'] = pd.cut(data['PUC_MARKS'], bins=[0, 60, 70, 80, 90, 100], labels=['Below 60', '60-70', '70-80', '80-90', '90-100'])
data['CGPA'] = pd.cut(data['CGPA'], bins=[0, 6, 7, 8, 9, 10], labels=['Below 6', '6-7', '7-8', '8-9', '9-10'])

# Group by each categorical variable and calculate counts of placed individuals
categorical_variables = ['REGION', 'INTERNSHIP', 'BRANCH', 'SSLC_MARKS', 'PUC_MARKS', 'CGPA']

plt.figure(figsize=(12, 8))

for i, category in enumerate(categorical_variables):
    placed_counts = data[data['STATUS'] == 'Placed'].groupby(category).size()
    total_count = data.groupby(category).size()
    percentages = (placed_counts / total_count) * 100

    # Plotting bar chart
    plt.subplot(2, 3, i+1)
    plt.bar(placed_counts.index, percentages, color='skyblue')
    plt.ylabel('Percentage (%)')
    plt.xticks(rotation=45, ha='right')

    # Adding percentage labels above each bar
    for j, percentage in enumerate(percentages):
        plt.text(j, percentage + 1, f"{percentage:.1f}%", ha='center')

    # Adding figure tag below each subplot with a 2 cm distance
    plt.text(0.5, -0.2, f"Figure 6.1.{i+1}: Placed Candidates by {category}", transform=plt.gca().transAxes, ha='center', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the dataset
data = pd.read_csv("new.csv")

# Categorize SSLC marks, PUC marks, and CGPA into bins
data['SSLC_MARKS'] = pd.cut(data['SSLC_MARKS'], bins=[0, 60, 70, 80, 90, 100], labels=['Below 60', '60-70', '70-80', '80-90', '90-100'])
data['PUC_MARKS'] = pd.cut(data['PUC_MARKS'], bins=[0, 60, 70, 80, 90, 100], labels=['Below 60', '60-70', '70-80', '80-90', '90-100'])
data['CGPA'] = pd.cut(data['CGPA'], bins=[0, 6, 7, 8, 9, 10], labels=['Below 6', '6-7', '7-8', '8-9', '9-10'])

# Group by each categorical variable and calculate counts of individuals
categorical_variables = ['REGION', 'INTERNSHIP', 'BRANCH', 'SSLC_MARKS', 'PUC_MARKS', 'CGPA']

# Set up subplots with 2 rows and 3 columns
plt.figure(figsize=(18, 12))

for i, category in enumerate(categorical_variables):
    placed_counts = data[data['STATUS'] == 'Placed'].groupby(category).size()
    total_counts = data.groupby(category).size()
    percentages = (placed_counts / total_counts) * 100
    categories = placed_counts.index

    # Plotting pie chart
    plt.subplot(2, 3, i+1)
    plt.pie(placed_counts, labels=categories, autopct='%1.1f%%', startangle=140)

    plt.axis('equal')  # Ensures the pie chart is drawn as a circle

    # Adding figure tag below each subplot
    plt.text(0.5, -0.2, f"Figure 6.2.{i+1}: Placed Candidates by {category}", transform=plt.gca().transAxes, ha='center', fontsize=12)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the dataset
data = pd.read_csv("new.csv")

# Categorize SSLC marks, PUC marks, and CGPA into bins
data['SSLC_MARKS'] = pd.cut(data['SSLC_MARKS'], bins=[0, 60, 70, 80, 90, 100], labels=['Below 60', '60-70', '70-80', '80-90', '90-100'])
data['PUC_MARKS'] = pd.cut(data['PUC_MARKS'], bins=[0, 60, 70, 80, 90, 100], labels=['Below 60', '60-70', '70-80', '80-90', '90-100'])
data['CGPA'] = pd.cut(data['CGPA'], bins=[0, 6, 7, 8, 9, 10], labels=['Below 6', '6-7', '7-8', '8-9', '9-10'])

# Group by each categorical variable and calculate counts of individuals
categorical_variables = ['REGION', 'INTERNSHIP', 'BRANCH', 'SSLC_MARKS', 'PUC_MARKS', 'CGPA']

# Set up subplots with 2 rows and 3 columns
plt.figure(figsize=(18, 12))

for i, category in enumerate(categorical_variables):
    placed_counts = data[data['STATUS'] == 'Placed'].groupby(category).size()
    total_counts = data.groupby(category).size()
    percentages = (placed_counts / total_counts) * 100
    categories = placed_counts.index

    # Plotting bar chart
    plt.subplot(2, 3, i+1)
    plt.bar(categories, percentages, color='skyblue')
    plt.ylabel('Percentage (%)')
    plt.xticks(rotation=45, ha='right')

    # Adding percentage labels above each bar
    for j, percentage in enumerate(percentages):
        plt.text(j, percentage + 1, f"{percentage:.1f}%", ha='center')

    # Adding figure tag below each subplot
    plt.text(0.5, -0.2, f"Figure 6.1.{i+1}: Placed Candidates by {category}", transform=plt.gca().transAxes, ha='center', fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
import tkinter as tk
from tkinter import messagebox
import pandas as pd
from sklearn.linear_model import LogisticRegression

# Function to predict placement
def predict_placement():
    # Get user input from entry fields
    gender = int(entry_gender.get())
    region = int(entry_region.get())
    sslc_marks = float(entry_sslc_marks.get())
    sslc_board = int(entry_sslc_board.get())
    puc_marks = float(entry_puc_marks.get())
    puc_board = int(entry_puc_board.get())
    cgpa = float(entry_cgpa.get())
    internship = int(entry_internship.get())
    work_experience = int(entry_work_experience.get())
    branch = int(entry_branch.get())

    # Create a DataFrame for test data
    test_data = pd.DataFrame({
        'GENDER': [gender],
        'REGION': [region],
        'SSLC_MARKS': [sslc_marks],
        'SSLC_BOARD': [sslc_board],
        'PUC_MARKS': [puc_marks],
        'PUC_BOARD': [puc_board],
        'CGPA': [cgpa],
        'INTERNSHIP': [internship],
        'WORK EXPERIENCE': [work_experience],
        'BRANCH': [branch],
    })

    # Load the dataset
    data = pd.read_csv("C:\\Users\\chait\\OneDrive\\Desktop\\MINI PROJECT\\MINIPROJECT\\PREDICTION\\new.csv")

    # Data preprocessing
    data = data.drop(['S.NO'], axis=1)
    data["GENDER"] = data["GENDER"].map({'Male': 0, 'Female': 1})
    data["REGION"] = data["REGION"].map({' Rural': 0, ' Urban': 1})
    data["SSLC_BOARD"] = data["SSLC_BOARD"].map({' State Board': 0, ' CBSE': 1, ' ICSE': 2})
    data["PUC_BOARD"] = data["PUC_BOARD"].map({" State Board": 0, " CBSE": 1})
    data["INTERNSHIP"] = data["INTERNSHIP"].map({"YES": 0, "NO": 1})
    data["WORK EXPERIENCE"] = data["WORK EXPERIENCE"].map({"YES": 0, "NO": 1})
    data["BRANCH"] = data["BRANCH"].map({" CS": 0, " ME": 1, " EE": 2, " IS": 3, " EC": 4, " CV": 5})
    data["STATUS"] = data["STATUS"].map({"Placed": 0, "NotPlaced": 1})

    # Splitting data into features and target variable
    x = data.drop('STATUS', axis=1)
    y = data['STATUS']

    # Logistic Regression Model
    lr = LogisticRegression()
    lr.fit(x, y)

    # Predict probability and result
    prob = lr.predict_proba(test_data)[0][1]
    prediction = lr.predict(test_data)

    # Display result
    if prediction == 1:
        messagebox.showinfo("Placement Prediction", f"Congratulations you have the chances of getting placed\nProbability of placement: {prob}")
    else:
        messagebox.showinfo("Placement Prediction", f"Sorry for this time! Work more harder and visit again\nProbability of placement: {prob}")

# Create the main window
root = tk.Tk()
root.title("Placement Prediction")

# Labels
tk.Label(root, text="Gender (0 for Male, 1 for Female):").grid(row=0, column=0)
tk.Label(root, text="Region (0 for Rural, 1 for Urban):").grid(row=1, column=0)
tk.Label(root, text="SSLC Marks:").grid(row=2, column=0)
tk.Label(root, text="SSLC Board (0 for State Board, 1 for CBSE, 2 for ICSE):").grid(row=3, column=0)
tk.Label(root, text="PUC Marks:").grid(row=4, column=0)
tk.Label(root, text="PUC Board (0 for State Board, 1 for CBSE):").grid(row=5, column=0)
tk.Label(root, text="CGPA:").grid(row=6, column=0)
tk.Label(root, text="Internship (0 for Yes, 1 for No):").grid(row=7, column=0)
tk.Label(root, text="Work Experience (0 for Yes, 1 for No):").grid(row=8, column=0)
tk.Label(root, text="Branch (0 for CS, 1 for ME, 2 for EE, 3 for IS, 4 for EC, 5 for CV):").grid(row=9, column=0)

# Entry fields
entry_gender = tk.Entry(root)
entry_gender.grid(row=0, column=1)
entry_region = tk.Entry(root)
entry_region.grid(row=1, column=1)
entry_sslc_marks = tk.Entry(root)
entry_sslc_marks.grid(row=2, column=1)
entry_sslc_board = tk.Entry(root)
entry_sslc_board.grid(row=3, column=1)
entry_puc_marks = tk.Entry(root)
entry_puc_marks.grid(row=4, column=1)
entry_puc_board = tk.Entry(root)
entry_puc_board.grid(row=5, column=1)
entry_cgpa = tk.Entry(root)
entry_cgpa.grid(row=6, column=1)
entry_internship = tk.Entry(root)
entry_internship.grid(row=7, column=1)
entry_work_experience = tk.Entry(root)
entry_work_experience.grid(row=8, column=1)
entry_branch = tk.Entry(root)
entry_branch.grid(row=9, column=1)

# Button
predict_button = tk.Button(root, text="Predict Placement", command=predict_placement)
predict_button.grid(row=10, column=0, columnspan=2)

root.mainloop()
