# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("dataset.csv")
data
# Out:
#      S.NO  GENDER  REGION  SSLC MARKS         BOARD  PUC MARKS       BOARD.1  \
# 0       1    Male   Urban        87.6          CBSE       95.0          CBSE
# 1       2    Male   Rural        78.4   State Board       85.0   State Board
# 2       3  Female   Urban        92.5          ICSE       90.2          ICSE
# 3       4  Female   Rural        83.9   State Board       81.6   State Board
# 4       5  Female   Rural        79.3   State Board       82.0   State Board
# ..    ...     ...     ...         ...           ...        ...           ...
# 695   696  Female   Rural        77.4   State Board       90.2   State Board
# 696   697    Male   Urban        86.7          ICSE       83.5          ICSE
# 697   698  Female   Rural        71.9   State Board       84.7   State Board
# 698   699    Male   Urban        78.5   State Board       85.5          ICSE
# 699   700  Female   Rural        79.2          ICSE       86.7          ICSE
#
#      CGPA INTERNSHIP WORK EXPERIENCE BRANCH STATUS
# 0     8.7        Yes              No     CS    YES
# 1     7.8         No              No     EC     NO
# 2     9.1        Yes              No     IS    YES
# 3     7.5         No              No     ME     NO
# 4     8.3        Yes              No     CS    YES
# ..    ...        ...             ...    ...    ...
# 695   7.3         No             Yes     IS     NO
# 696   8.9        Yes             Yes     CS    YES
# 697   8.1         No              No     EC     NO
# 698   7.3         No              No     CS     NO
# 699   7.7         No              No     EE     NO
#
# [700 rows x 12 columns]

# %%
data.shape
# Out:
# (700, 12)

# %%
print("Number of Rows",data.shape[0])
print("Number of columns",data.shape[1])
# Out:
# Number of Rows 700
# Number of columns 12

# %% [raw]
# DATA PREPROCESSING

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   S.NO             700 non-null    int64
#  1   GENDER           700 non-null    object
#  2   REGION           700 non-null    object
#  3   SSLC MARKS       700 non-null    float64
#  4   BOARD            700 non-null    object
#  5   PUC MARKS        700 non-null    float64
#  6   BOARD.1          700 non-null    object
#  7   CGPA             700 non-null    float64
#  8   INTERNSHIP       700 non-null    object
#  9   WORK EXPERIENCE  700 non-null    object
#  10  BRANCH           700 non-null    object
#  11  STATUS           700 non-null    object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 65.8+ KB

# %%
data.isnull()
# Out:
#       S.NO  GENDER  REGION  SSLC MARKS  BOARD  PUC MARKS  BOARD.1   CGPA  \
# 0    False   False   False       False  False      False    False  False
# 1    False   False   False       False  False      False    False  False
# 2    False   False   False       False  False      False    False  False
# 3    False   False   False       False  False      False    False  False
# 4    False   False   False       False  False      False    False  False
# ..     ...     ...     ...         ...    ...        ...      ...    ...
# 695  False   False   False       False  False      False    False  False
# 696  False   False   False       False  False      False    False  False
# 697  False   False   False       False  False      False    False  False
# 698  False   False   False       False  False      False    False  False
# 699  False   False   False       False  False      False    False  False
#
#      INTERNSHIP  WORK EXPERIENCE  BRANCH  STATUS
# 0         False            False   False   False
# 1         False            False   False   False
# 2         False            False   False   False
# 3         False            False   False   False
# 4         False            False   False   False
# ..          ...              ...     ...     ...
# 695       False            False   False   False
# 696       False            False   False   False
# 697       False            False   False   False
# 698       False            False   False   False
# 699       False            False   False   False
#
# [700 rows x 12 columns]

# %%
data.isnull().sum()
# Out:
# S.NO               0
# GENDER             0
# REGION             0
# SSLC MARKS         0
# BOARD              0
# PUC MARKS          0
# BOARD.1            0
# CGPA               0
# INTERNSHIP         0
# WORK EXPERIENCE    0
# BRANCH             0
# STATUS             0
# dtype: int64

# %% [raw]
# EXPLORATORY DATA ANALYSIS

# %%
data.columns
# Out:
# Index(['S.NO', 'GENDER', 'REGION', 'SSLC MARKS', 'BOARD', 'PUC MARKS',
#        'BOARD.1', 'CGPA', 'INTERNSHIP', 'WORK EXPERIENCE', 'BRANCH', 'STATUS'],
#       dtype='object')

# %%
data['STATUS'].unique()
# Out:
# array(['YES', 'NO'], dtype=object)

# %%
data['STATUS'].value_counts()
# Out:
# STATUS
# YES    373
# NO     327
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['S.NO', 'GENDER', 'REGION', 'SSLC MARKS', 'BOARD', 'PUC MARKS',
#        'BOARD.1', 'CGPA', 'INTERNSHIP', 'WORK EXPERIENCE', 'BRANCH', 'STATUS'],
#       dtype='object')

# %%
data=data.drop(['S.NO'],axis=1)

# %%
data.head(1)
# Out:
#   GENDER  REGION  SSLC MARKS  BOARD  PUC MARKS BOARD.1  CGPA INTERNSHIP  \
# 0   Male   Urban        87.6   CBSE       95.0    CBSE   8.7        Yes
#
#   WORK EXPERIENCE BRANCH STATUS
# 0              No     CS    YES
